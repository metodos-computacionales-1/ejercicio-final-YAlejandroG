# %%
import matplotlib.pylab as plt
import numpy as np
from IPython.display import clear_output

# %%
# %%bash
# g++ pendulum.cpp
# ./a.out 10000000 >pendulum.txt

# %%
pendulum = np.genfromtxt("pendulum.txt")

time = pendulum[:,0]
theta = pendulum[:,1]
omega = pendulum[:,2]
omega
# Out:
# array([-1.73501, -1.80794, -1.76229, ...,  1.08673,  1.08353,  1.0803 ])

# %%
plt.figure(figsize=(15,4))
plt.plot(time,theta,c='g')
plt.grid()
plt.xlabel('time (s)')
plt.ylabel('$\Theta$ (rads)')
plt.show()

# %%
for i in range(10,len(theta),100):
    plt.plot(theta[:1],omega[:1],'.',c='g')
    plt.ylim(-3,1.5)
    plt.xlim(-3.5,3.5)
    plt.savefig(str(i).zfill(4)+'.png')
    plt.close()
    if i>10**4:
        break;
